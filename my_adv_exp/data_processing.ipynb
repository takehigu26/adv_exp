# %% [markdown]
# # Titanic

# %%
import pandas as pd
train = pd.read_csv('datasets/titanic/train.csv')
#df_ts = pd.read_csv('datasets/titanic/test.csv')

# %%
combine1 = [train]

for train in combine1: 
        train['Salutation'] = train.Name.str.extract(' ([A-Za-z]+).', expand=False) 
for train in combine1: 
        train['Salutation'] = train['Salutation'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
        train['Salutation'] = train['Salutation'].replace('Mlle', 'Miss')
        train['Salutation'] = train['Salutation'].replace('Ms', 'Miss')
        train['Salutation'] = train['Salutation'].replace('Mme', 'Mrs')
        del train['Name']
Salutation_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5} 
for train in combine1: 
        train['Salutation'] = train['Salutation'].map(Salutation_mapping) 
        train['Salutation'] = train['Salutation'].fillna(0)

# %%
import numpy as np
for train in combine1: 
        train['Ticket_Lett'] = train['Ticket'].apply(lambda x: str(x)[0])
        train['Ticket_Lett'] = train['Ticket_Lett'].apply(lambda x: str(x)) 
        train['Ticket_Lett'] = np.where((train['Ticket_Lett']).isin(['1', '2', '3', 'S', 'P', 'C', 'A']), train['Ticket_Lett'], np.where((train['Ticket_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']), '0','0')) 
        train['Ticket_Len'] = train['Ticket'].apply(lambda x: len(x)) 
        del train['Ticket'] 
train['Ticket_Lett']=train['Ticket_Lett'].replace("1",1).replace("2",2).replace("3",3).replace("0",0).replace("S",3).replace("P",0).replace("C",3).replace("A",3)

# %%
for train in combine1: 
    train['Cabin_Lett'] = train['Cabin'].apply(lambda x: str(x)[0]) 
    train['Cabin_Lett'] = train['Cabin_Lett'].apply(lambda x: str(x)) 
    train['Cabin_Lett'] = np.where((train['Cabin_Lett']).isin([ 'F', 'E', 'D', 'C', 'B', 'A']),train['Cabin_Lett'], np.where((train['Cabin_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']), '0','0'))
del train['Cabin'] 
train['Cabin_Lett']=train['Cabin_Lett'].replace("A",1).replace("B",2).replace("C",1).replace("0",0).replace("D",2).replace("E",2).replace("F",1)

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
for train in combine1:
    train['IsAlone'] = 0
    train.loc[train['FamilySize'] == 1, 'IsAlone'] = 1

# %%
train = pd.get_dummies(data=train, dummy_na=True)

# %%
train.loc[train['Age'], 'Age'].mean()
# Out:
# 27.662447257383967

# %%
train = train.fillna({'Age': train.loc[train['Age'], 'Age'].mean()})

# %%
train.to_csv('datasets/titanic/my_titanic.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Salutation  \
# 0            1         0       3  22.0      1      0   7.2500         1.0
# 1            2         1       1  38.0      1      0  71.2833         3.0
# 2            3         1       3  26.0      0      0   7.9250         2.0
# 3            4         1       1  35.0      1      0  53.1000         3.0
# 4            5         0       3  35.0      0      0   8.0500         1.0
#
#    Ticket_Lett  Ticket_Len  Cabin_Lett  FamilySize  IsAlone  Sex_female  \
# 0            3           9           0           2        0           0
# 1            0           8           1           2        0           1
# 2            3          16           0           1        1           1
# 3            1           6           1           2        0           1
# 4            3           6           0           1        1           0
#
#    Sex_male  Sex_nan  Embarked_C  Embarked_Q  Embarked_S  Embarked_nan
# ...

# %% [markdown]
# # German Credit

# %%
cols = ['Account Status', 'Months', 'Credit History', 'Purpose', 'Credit Amount', 'Savings',
        'Employment', 'Installment Rate', 'Personal Status', 'Guarantors', 'Residence',
        'Property', 'Age', 'Other Installments', 'Housing', 'Credit Cards', 'Job', 'Dependents',
        'Phone', 'Foreign Worker', 'Credit Rating']

# %%
g = pd.read_csv('datasets/german/german.data', header=None)

# %%
g.at[0,0].split()
dic_array = []
ori_dic = {col:0 for col in cols}
for i in range(int(g.shape[0])):
    l = g.at[i, 0].split()
    dic = ori_dic.copy()
    dic = {cols[j]: l[j] for j in range(len(cols))}
    dic_array.append(dic)

# %%
german = pd.DataFrame(dic_array)

# %% [markdown]
# def f(feature, fun):
#     german[feature] = german[feature].map(fun)
# def u(feature):
#     print(german[feature].unique())
# f1 = lambda s: int(s[2:])-1
# f2 = lambda s: int(s)
# f3 = lambda s: int(s[3:])-1
# f4 = lambda s: int(s) - 1
# f5 = lambda s: int(s[2:])
# f('Account Status', f1)
# f('Months', f2)
# f('Credit History', f5)
# f('Purpose', f1)
# f('Credit Amount', f2)
# f('Savings', f1)
# f('Employment', f1)
# f('Installment Rate', f2)
# f('Personal Status', f1)
# f('Guarantors', f1)
# f('Residence', f2)
# f('Property', f3)
# f('Age', f2)
# f('Other Installments', f3)
# f('Housing', f3)
# f('Credit Cards', f2)
# f('Job', f3)
# f('Dependents', f2)
# f('Phone', f1)
# f('Foreign Worker', f3)
# f('Credit Rating', f4)

# %%
german.head()
# Out:
#   Account Status Months Credit History Purpose Credit Amount Savings  \
# 0            A11      6            A34     A43          1169     A65
# 1            A12     48            A32     A43          5951     A61
# 2            A14     12            A34     A46          2096     A61
# 3            A11     42            A32     A42          7882     A61
# 4            A11     24            A33     A40          4870     A61
#
#   Employment Installment Rate Personal Status Guarantors  ... Property Age  \
# 0        A75                4             A93       A101  ...     A121  67
# 1        A73                2             A92       A101  ...     A121  22
# 2        A74                2             A93       A101  ...     A121  49
# 3        A74                2             A93       A103  ...     A122  45
# 4        A73                3             A93       A101  ...     A124  53
#
#   Other Installments Housing Credit Cards   Job Dependents Phone  \
# ...

# %%
categorical_cols = ['Account Status', 'Credit History', 'Purpose', 'Savings',
        'Employment', 'Personal Status', 'Guarantors',
        'Property', 'Other Installments', 'Housing', 'Job', 
        'Phone', 'Foreign Worker', 'Credit Rating']
onehot_cols = ['Account Status', 'Credit History', 'Purpose', 'Savings',
        'Employment', 'Personal Status', 'Guarantors',
        'Property', 'Other Installments', 'Housing', 'Job']

# %%
german

# %%
german.to_csv('datasets/german/my_german.csv')

# %%
def f(feature, fun):
    german[feature] = german[feature].map(fun)
def u(feature):
    print(german[feature].unique())
f2 = lambda s: int(s)
f4 = lambda s: int(s) - 1
f('Months', f2)
f('Credit Amount', f2)
f('Installment Rate', f2)
f('Residence', f2)
f('Age', f2)
f('Credit Cards', f2)
f('Dependents', f2)
f('Phone', f1)
f('Foreign Worker', f3)
f('Credit Rating', f4)

# %%
german = pd.get_dummies(german)

# %%
german.head()
# Out:
#    Months  Credit Amount  Installment Rate  Residence  Age  Credit Cards  \
# 0       6           1169                 4          4   67             2
# 1      48           5951                 2          2   22             1
# 2      12           2096                 2          3   49             1
# 3      42           7882                 2          4   45             1
# 4      24           4870                 3          4   53             2
#
#    Dependents  Phone  Foreign Worker  Credit Rating  ...  \
# 0           1     91               0              0  ...
# 1           1     90               0              1  ...
# 2           2     90               0              0  ...
# 3           2     90               0              0  ...
# 4           2     90               0              1  ...
#
#    Other Installments_A141  Other Installments_A142  Other Installments_A143  \
# 0                        0                        0                        1
# ...

# %%
german.shape
# Out:
# (1000, 60)

# %%
cols = list(german.columns)
cols.remove('Credit Rating')
cols = cols + ['Credit Rating']
german = german.reindex(columns=cols)

# %%
german.head()
# Out:
#    Months  Credit Amount  Installment Rate  Residence  Age  Credit Cards  \
# 0       6           1169                 4          4   67             2
# 1      48           5951                 2          2   22             1
# 2      12           2096                 2          3   49             1
# 3      42           7882                 2          4   45             1
# 4      24           4870                 3          4   53             2
#
#    Dependents  Phone  Foreign Worker  Account Status_A11  ...  \
# 0           1     91               0                   1  ...
# 1           1     90               0                   0  ...
# 2           2     90               0                   0  ...
# 3           2     90               0                   1  ...
# 4           2     90               0                   1  ...
#
#    Other Installments_A142  Other Installments_A143  Housing_A151  \
# 0                        0                        1             0
# ...

# %%
german.to_csv('datasets/german/my_german_numeric.csv')

# %% [markdown]
# # Compas

# %%
import pandas as pd
compas = pd.read_csv('datasets/compas/compas-scores-two-years.csv')
compas.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  ...  v_decile_score  \
# 0  1947-04-18   69  Greater than 45             Other  ...               1
# 1  1982-01-22   34          25 - 45  African-American  ...               1
# 2  1991-05-14   24     Less than 25  African-American  ...               3
# 3  1993-01-21   23     Less than 25  African-American  ...               6
# 4  1973-01-22   43          25 - 45             Other  ...               1
#
# ...

# %%
compas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7214 entries, 0 to 7213
# Data columns (total 53 columns):
# id                         7214 non-null int64
# name                       7214 non-null object
# first                      7214 non-null object
# last                       7214 non-null object
# compas_screening_date      7214 non-null object
# sex                        7214 non-null object
# dob                        7214 non-null object
# age                        7214 non-null int64
# age_cat                    7214 non-null object
# race                       7214 non-null object
# juv_fel_count              7214 non-null int64
# decile_score               7214 non-null int64
# juv_misd_count             7214 non-null int64
# juv_other_count            7214 non-null int64
# priors_count               7214 non-null int64
# days_b_screening_arrest    6907 non-null float64
# c_jail_in                  6907 non-null object
# ...

# %% [markdown]
# # COMPAS

# %%
import pandas as pd
compas = pd.read_csv('datasets/compas/compas-scores-two-years.csv')

# %%
compas.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  ...  v_decile_score  \
# 0  1947-04-18   69  Greater than 45             Other  ...               1
# 1  1982-01-22   34          25 - 45  African-American  ...               1
# 2  1991-05-14   24     Less than 25  African-American  ...               3
# 3  1993-01-21   23     Less than 25  African-American  ...               6
# 4  1973-01-22   43          25 - 45             Other  ...               1
#
# ...

# %%
compas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7214 entries, 0 to 7213
# Data columns (total 53 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       7214 non-null   int64
#  1   name                     7214 non-null   object
#  2   first                    7214 non-null   object
#  3   last                     7214 non-null   object
#  4   compas_screening_date    7214 non-null   object
#  5   sex                      7214 non-null   object
#  6   dob                      7214 non-null   object
#  7   age                      7214 non-null   int64
#  8   age_cat                  7214 non-null   object
#  9   race                     7214 non-null   object
#  10  juv_fel_count            7214 non-null   int64
#  11  decile_score             7214 non-null   int64
#  12  juv_misd_count           7214 non-null   int64
#  13  juv_other_count          7214 non-null   int64
# ...

# %%
from aif360.datasets import CompasDataset
compas = CompasDataset()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# IOError: [Errno 2] No such file or directory: '/home/t.higuchi/.local/share/virtualenvs/adv_exp-_HUDcmbj/lib/python3.7/site-packages/aif360/datasets/../data/raw/compas/compas-scores-two-years.csv'
# To use this class, please download the following file:
#
# 	https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-two-years.csv
#
# and place it, as-is, in the folder:
#
# 	/home/t.higuchi/.local/share/virtualenvs/adv_exp-_HUDcmbj/lib/python3.7/site-packages/aif360/data/raw/compas
#
# Traceback (most recent call last):
#   File "/home/t.higuchi/.local/share/virtualenvs/adv_exp-_HUDcmbj/lib/python3.7/site-packages/aif360/datasets/compas_dataset.py", line 68, in __init__
#     df = pd.read_csv(filepath, index_col='id', na_values=na_values)
# ...
